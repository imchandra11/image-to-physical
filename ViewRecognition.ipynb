# %%
from ObjectDetection.modelmodule import ModelModuleOD
from ObjectDetection.datamodule import DataModuleOD

# %run ObjectDetection/main_fittest.py --config ViewRecognition/config/viewrecognition.yaml --config ViewRecognition/config/viewrecognition.local.yaml 

# %run ObjectDetection/main.py fit --config ViewRecognition/config/viewrecognition.yaml --config ViewRecognition/config/viewrecognition.local.yaml 
# %run ObjectDetection/main.py test --config ViewRecognition/config/viewrecognition.yaml --config ViewRecognition/config/viewrecognition.local.yaml  --ckpt_path "E:\AIOutput\ViewRecognition\version_0\checkpoints\epoch=2-val_loss=0.37.best.ckpt"
# %run ObjectDetection/main.py predict --config ViewRecognition/config/viewrecognition.yaml --config ViewRecognition/config/viewrecognition.local.yaml --data.data_dir "E:\AIData\Bbox_Dataset\Testing" --ckpt_path "E:\AIOutput\ViewRecognition\version_0\checkpoints\epoch=2-val_loss=0.32.best.ckpt"
